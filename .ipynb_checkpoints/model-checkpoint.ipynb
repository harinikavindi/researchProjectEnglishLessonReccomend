# %%
import pandas as pd 
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import TruncatedSVD
import warnings
warnings.filterwarnings('ignore')



students = pd.read_csv('data.csv', sep=',' )
students.head()
#print(students)

#students.groupby('lesson_title')['rating'].mean().head()
students.groupby('lesson_title')['rating'].mean().sort_values(ascending=False).head()

ratings_mean_count = pd.DataFrame(students.groupby('lesson_title')['rating'].mean())
#print(ratings_mean_count)

################ ratings_mean_count['rating_counts'] = pd.DataFrame(students.groupby('lesson_title')['rating'].count())
################ print(ratings_mean_count)

ratings_mean_count.head()

sns.set_style('dark')
# %matplotlib inline

# ################plt.figure(figsize=(8,6))
# ###########plt.rcParams['patch.force_edgecolor'] = True
# ##############ratings_mean_count['rating_counts'].hist(bins=50)

plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
ratings_mean_count['rating'].hist(bins=50)

################# plt.figure(figsize=(8,6))
################# plt.rcParams['patch.force_edgecolor'] = True
################# sns.jointplot(x='rating', y='rating_counts', data=ratings_mean_count, alpha=0.4)

student_rating = students.pivot_table(index='student_id', columns='lesson_title', values='rating')

student_rating.head()
#print(student_rating)

lesson_ratings = student_rating['D']
lesson_ratings.head()
print(lesson_ratings)

model = student_rating.corrwith(lesson_ratings)

corr_lesson = pd.DataFrame(model, columns=['Correlation'])
corr_lesson.dropna(inplace=True)
corr_lesson.head()
print(corr_lesson)

corr_lesson.sort_values('Correlation', ascending=False).head(10)

#pickle file create
import pickle

#### Test that the app works
import requests
import json

##### pickle file can be found inside the same directory as your Jupyter notebook.
pickle.dump(model, open('model.pkl', 'wb'))


# create a variavle with local url
url = 'http://127.0.0.1:5000'

# test data  -- Create sample data and convert to JSON
data = {'student_rating': 'D'}


data = json.dumps(data)
data

#Post sample data and check response code using 
r_survey = requests.post(url, data)
print(r_survey)
# Out:
# student_id
# 1     4
# 2     5
# 3     5
# 4     5
# 5     3
# 6     4
# 7     5
# 8     1
# 9     4
# 10    4
# 11    4
# 12    2
# 13    4
# 14    4
# 15    3
# 16    4
# 17    2
# 18    3
# 19    3
# 20    2
# 21    3
# 22    1
# 23    5
# 24    4
# 25    2
# 26    4
# 27    4
# 28    4
# 29    4
# 30    4
# 31    4
# 32    5
# 33    4
# 34    4
# 35    4
# 36    5
# 37    4
# 38    3
# 39    5
# 40    5
# 41    4
# 42    4
# 43    5
# 44    4
# 45    2
# 46    3
# 47    4
# 48    3
# 49    2
# 50    4
# Name: D, dtype: int64
#               Correlation
# lesson_title
# A                0.381881
# B                0.348083
# C                0.376083
# D                1.000000
# E                0.135209
# F                0.234480
# G                0.324930
# H                0.140372
# I                0.361906
# J                0.088779
# K                0.297006
# L                0.347129
# M                0.317936
# N                0.477403
# O                0.111901
# P                0.184210
# Q                0.315427
# R                0.236951
# S                0.374279
# T                0.247844
# U                0.192469
# <Response [500]>

# %%
##### pickle file can be found inside the same directory as your Jupyter notebook.
pickle.dump(corr_lesson, open('model.pkl', 'wb'))


# create a variavle with local url
url = 'http://127.0.0.1:5000'

# test data  -- Create sample data and convert to JSON
data = {  'student_rating': 'D'}


data = json.dumps(data)
data

#Post sample data and check response code using 
r_survey = requests.post(url, data)
print(r_survey)
# Out:
# <Response [500]>
